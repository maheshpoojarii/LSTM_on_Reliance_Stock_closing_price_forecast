# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from datetime import datetime
import plotly.graph_objects as go
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense,LSTM,Dropout
from keras import optimizers

# %%
data = pd.read_csv("/content/reliance_data.csv")
data.head()
# Out:
#          Date    Symbol Series  Prev Close    Open    High     Low  Last  \
# 0  01-01-1996  RELIANCE     EQ      204.65  205.00  206.10  203.65   NaN
# 1  02-01-1996  RELIANCE     EQ      205.75  205.25  206.25  202.65   NaN
# 2  03-01-1996  RELIANCE     EQ      204.15  207.50  216.95  205.25   NaN
# 3  04-01-1996  RELIANCE     EQ      205.70  203.75  204.40  201.05   NaN
# 4  05-01-1996  RELIANCE     EQ      203.80  203.00  203.00  200.65   NaN
#
#     Close    VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# 0  205.75  205.26  3717450  7.630000e+13     NaN                 NaN
# 1  204.15  204.13  6024650  1.230000e+14     NaN                 NaN
# 2  205.70  207.04  7473500  1.550000e+14     NaN                 NaN
# 3  203.80  202.47  7744000  1.570000e+14     NaN                 NaN
# 4  202.40  202.05  5952000  1.200000e+14     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
data.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  6205.000000  6205.000000  6205.000000  6205.000000  5657.000000
# mean    864.978445   866.381176   878.763811   852.795649   925.596986
# std     588.711275   590.165211   599.625939   578.473998   581.604138
# min       0.000000   102.600000   105.600000    99.600000   101.600000
# 25%     335.200000   335.000000   340.700000   329.500000   437.550000
# 50%     850.650000   852.500000   862.000000   842.100000   892.350000
# 75%    1089.400000  1091.100000  1107.000000  1073.950000  1129.900000
# max    3220.850000  3298.000000  3298.000000  3141.300000  3223.000000
#
#              Close         VWAP        Volume      Turnover        Trades  \
# count  6205.000000  6205.000000  6.205000e+03  6.205000e+03  2.356000e+03
# mean    865.291289   865.851146  6.215219e+06  5.187662e+14  1.383690e+05
# std     588.763023   588.941488  5.479271e+06  7.539147e+14  1.260736e+05
# min     101.300000   101.840000  5.282000e+04  3.480000e+12  2.991000e+03
# 25%     335.350000   335.710000  3.021751e+06  1.840000e+14  7.119900e+04
# 50%     850.700000   851.680000  4.602904e+06  3.270000e+14  9.841550e+04
# 75%    1089.850000  1089.480000  7.304408e+06  5.730000e+14  1.559778e+05
# max    3220.850000  3197.750000  6.523089e+07  1.473430e+16  1.428490e+06
#
#        Deliverable Volume  %Deliverble
# count        4.693000e+03  4693.000000
# mean         2.239901e+06     0.436332
# std          1.861021e+06     0.145526
# min          2.909700e+04     0.076300
# 25%          1.178486e+06     0.323000
# 50%          1.784092e+06     0.452300
# 75%          2.685974e+06     0.546300
# max          3.495888e+07     0.978300

# %%
data['Date'] = pd.to_datetime(data['Date'], format='%d-%m-%Y')

# %%
data.head(25)
# Out:
#          Date    Symbol Series  Prev Close    Open    High     Low  Last  \
# 0  1996-01-01  RELIANCE     EQ      204.65  205.00  206.10  203.65   NaN
# 1  1996-01-02  RELIANCE     EQ      205.75  205.25  206.25  202.65   NaN
# 2  1996-01-03  RELIANCE     EQ      204.15  207.50  216.95  205.25   NaN
# 3  1996-01-04  RELIANCE     EQ      205.70  203.75  204.40  201.05   NaN
# 4  1996-01-05  RELIANCE     EQ      203.80  203.00  203.00  200.65   NaN
# 5  1996-01-08  RELIANCE     EQ      202.40  202.00  202.15  192.30   NaN
# 6  1996-01-09  RELIANCE     EQ      194.30  188.55  192.00  182.25   NaN
# 7  1996-01-10  RELIANCE     EQ      188.70  185.00  189.45  183.00   NaN
# 8  1996-01-11  RELIANCE     EQ      183.85  182.00  190.50  181.75   NaN
# 9  1996-01-12  RELIANCE     EQ      189.60  191.00  192.45  186.35   NaN
# 10 1996-01-15  RELIANCE     EQ      187.60  187.05  188.00  184.60   NaN
# 11 1996-01-16  RELIANCE     EQ      185.65  185.00  187.00  184.40   NaN
# 12 1996-01-17  RELIANCE     EQ      186.00  185.00  185.25  177.05   NaN
# 13 1996-01-18  RELIANCE     EQ      178.60  174.05  176.90  171.80   NaN
# 14 1996-01-19  RELIANCE     EQ      173.65  171.25  173.40  169.45   NaN
# 15 1996-01-22  RELIANCE     EQ      170.60  171.15  175.75  171.00   NaN
# 16 1996-01-23  RELIANCE     EQ      173.50  174.10  174.85  157.00   NaN
# 17 1996-01-24  RELIANCE     EQ      166.15  164.70  165.70  158.00   NaN
# 18 1996-01-25  RELIANCE     EQ      160.45  160.10  160.80  152.75   NaN
# 19 1996-01-29  RELIANCE     EQ      153.70  153.00  167.25  152.05   NaN
# 20 1996-01-30  RELIANCE     EQ      165.80  171.00  189.00  168.50   NaN
# 21 1996-01-31  RELIANCE     EQ      180.70  179.00  185.75  172.25   NaN
# 22 1996-02-01  RELIANCE     EQ      176.75  175.00  185.00  174.50   NaN
# 23 1996-02-02  RELIANCE     EQ      183.85  188.75  206.00  188.75   NaN
# 24 1996-02-05  RELIANCE     EQ      203.80  215.00  225.20  208.55   NaN
#
#      Close    VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# 0   205.75  205.26   3717450  7.630000e+13     NaN                 NaN
# 1   204.15  204.13   6024650  1.230000e+14     NaN                 NaN
# 2   205.70  207.04   7473500  1.550000e+14     NaN                 NaN
# 3   203.80  202.47   7744000  1.570000e+14     NaN                 NaN
# 4   202.40  202.05   5952000  1.200000e+14     NaN                 NaN
# 5   194.30  197.57   6675550  1.320000e+14     NaN                 NaN
# 6   188.70  186.15  13880150  2.580000e+14     NaN                 NaN
# 7   183.85  186.24   9875700  1.840000e+14     NaN                 NaN
# 8   189.60  185.82  14625600  2.720000e+14     NaN                 NaN
# 9   187.60  188.95  13377500  2.530000e+14     NaN                 NaN
# 10  185.65  186.15   7139950  1.330000e+14     NaN                 NaN
# 11  186.00  185.71   7756400  1.440000e+14     NaN                 NaN
# 12  178.60  181.66  10697700  1.940000e+14     NaN                 NaN
# 13  173.65  174.42  13478000  2.350000e+14     NaN                 NaN
# 14  170.60  171.23  11586900  1.980000e+14     NaN                 NaN
# 15  173.50  173.80  12089550  2.100000e+14     NaN                 NaN
# 16  166.15  170.68  12671700  2.160000e+14     NaN                 NaN
# 17  160.45  161.39  12538400  2.020000e+14     NaN                 NaN
# 18  153.70  157.11  12883650  2.020000e+14     NaN                 NaN
# 19  165.80  160.64  23310600  3.740000e+14     NaN                 NaN
# 20  180.70  174.76  37914350  6.630000e+14     NaN                 NaN
# 21  176.75  179.43  26118950  4.690000e+14     NaN                 NaN
# 22  183.85  180.21  22865050  4.120000e+14     NaN                 NaN
# 23  203.80  196.45  29231000  5.740000e+14     NaN                 NaN
# 24  220.75  216.42  43646350  9.450000e+14     NaN                 NaN
#
#     %Deliverble
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN

# %%
df = data.loc[data["Date"].dt.year==2020,:];
df.describe()
# Out:
#                                 Date   Prev Close         Open         High  \
# count                            230   230.000000   230.000000   230.000000
# mean   2020-06-16 05:06:46.956521728  1719.122391  1724.650217  1750.653043
# min              2020-01-01 00:00:00   884.050000   916.200000   950.000000
# 25%              2020-03-23 06:00:00  1445.100000  1453.762500  1472.712500
# 50%              2020-06-18 12:00:00  1636.800000  1656.500000  1702.375000
# 75%              2020-09-07 18:00:00  2086.575000  2090.800000  2121.750000
# max              2020-11-27 00:00:00  2324.550000  2325.000000  2369.350000
# std                              NaN   375.712569   378.727660   376.589171
#
#                Low         Last        Close         VWAP        Volume  \
# count   230.000000   230.000000   230.000000   230.000000  2.300000e+02
# mean   1695.951957  1722.063913  1720.930000  1723.406565  1.844649e+07
# min     875.650000   891.000000   884.050000   899.320000  2.411900e+06
# 25%    1430.112500  1446.500000  1445.100000  1452.515000  1.145554e+07
# 50%    1633.800000  1685.200000  1680.000000  1677.250000  1.568513e+07
# 75%    2061.887500  2092.000000  2086.575000  2091.435000  2.275622e+07
# max    2310.550000  2324.900000  2324.550000  2339.460000  6.523089e+07
# std     376.610897   375.639812   375.721744   377.008872  1.093071e+07
#
#            Turnover        Trades  Deliverable Volume  %Deliverble
# count  2.300000e+02  2.300000e+02        2.300000e+02   230.000000
# mean   3.172958e+15  4.054413e+05        5.665088e+06     0.329247
# min    4.838160e+14  9.948400e+04        6.214850e+05     0.114800
# 25%    1.880250e+15  2.658772e+05        3.241737e+06     0.238400
# 50%    2.720000e+15  3.490370e+05        5.036454e+06     0.307200
# 75%    3.714092e+15  5.020468e+05        7.181379e+06     0.407800
# max    1.473430e+16  1.428490e+06        1.919505e+07     0.656700
# std    2.070710e+15  2.183448e+05        3.242581e+06     0.117424

# %%
candlestick = go.Candlestick(
                            x=df.index,
                            open=df['Open'],
                            high=df['High'],
                            low=df['Low'],
                            close=df['Close']
                            )
fig = go.Figure(data=[candlestick])

fig.update_layout(
    width=1200, height=600,
    title="Reliance, 2020",
    yaxis_title='Price'

)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="eede6c1d-6b34-4a85-b0e8-3ef7d85f58b4" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eede6c1d-6b34-4a85-b0e8-3ef7d85f58b4")) {                    Plotly.newPlot(                        "eede6c1d-6b34-4a85-b0e8-3ef7d85f58b4",                        [{"close":[1509.6,1535.3,1537.15,1501.5,1524.6,1513.15,1548.0,1547.65,1543.7,1529.4,1523.85,1537.9,1581.0,1532.35,1533.9,1533.35,1526.85,1521.55,1506.55,1471.75,1479.85,1443.75,1411.65,1383.35,1385.5,1426.4,1448.5,1457.8,1433.65,1435.6,1452.75,1470.3,1474.15,1487.6,1478.25,1467.4,1503.8,1485.95,1444.95,1416.4,1392.0,1386.25,1328.65,1316.15,1342.85,1339.7,1311.15,1271.0,1114.15,1153.55,1063.0,1105.3,1015.7,1008.0,968.5,917.7,1017.95,884.05,943.4,1082.25,1066.2,1065.6,1030.45,1113.75,1080.45,1077.45,1206.1,1192.15,1219.95,1189.15,1149.85,1168.05,1224.0,1243.8,1237.35,1363.6,1370.9,1417.0,1429.75,1428.15,1426.95,1466.0,1435.2,1460.65,1460.75,1506.95,1561.8,1576.8,1479.25,1496.45,1435.95,1459.4,1440.75,1408.9,1433.7,1441.25,1431.55,1424.05,1445.55,1472.25,1464.4,1520.35,1535.7,1541.65,1579.8,1581.7,1569.5,1537.15,1572.15,1537.7,1588.8,1614.55,1617.7,1615.35,1655.9,1759.4,1746.15,1720.9,1727.85,1717.9,1741.65,1723.15,1704.1,1737.6,1760.35,1787.9,1851.8,1823.45,1798.0,1824.25,1878.05,1935.0,1917.0,1844.0,1843.4,1911.7,1919.9,1971.55,2004.0,2057.8,2146.15,2156.2,2177.7,2096.65,2108.85,2067.1,2009.0,2150.6,2126.45,2134.1,2146.45,2119.85,2133.8,2127.6,2122.05,2113.8,2091.35,2118.55,2131.55,2097.05,2081.85,2095.75,2082.1,2137.3,2110.6,2116.15,2080.7,2087.25,2128.2,2112.1,2077.25,2082.65,2107.1,2161.35,2314.0,2319.75,2302.55,2318.85,2324.55,2298.75,2305.7,2255.85,2211.15,2230.8,2181.2,2201.7,2216.25,2245.05,2234.35,2225.25,2212.2,2210.35,2257.5,2239.25,2233.45,2237.05,2280.7,2287.5,2206.5,2175.8,2176.2,2155.9,2124.6,2106.95,2113.05,2029.1,2034.5,2011.45,2026.9,2054.5,1877.45,1850.4,1913.2,1955.0,2029.15,2050.7,2084.55,1997.2,1980.0,1996.4,2002.3,1993.25,1987.2,1973.15,1899.5,1950.7,1964.05,1947.8,1952.6,1929.8],"high":[1527.1,1540.95,1541.65,1527.9,1534.5,1534.45,1550.0,1557.95,1558.7,1550.0,1539.9,1543.35,1584.95,1609.0,1545.85,1546.75,1541.95,1536.35,1524.45,1510.0,1494.4,1479.7,1453.25,1426.95,1399.95,1432.5,1452.8,1467.0,1452.35,1445.5,1466.2,1474.85,1477.75,1501.45,1506.15,1475.9,1506.45,1508.0,1477.0,1451.4,1412.35,1393.8,1357.0,1369.0,1353.9,1353.8,1357.95,1288.15,1241.0,1178.45,1101.0,1140.0,1079.7,1060.0,1035.9,967.0,1034.9,950.0,970.0,1151.55,1116.9,1107.3,1074.8,1129.8,1124.6,1134.45,1214.0,1229.0,1232.8,1215.0,1236.0,1187.45,1230.0,1257.0,1252.0,1384.9,1385.85,1494.95,1475.0,1455.45,1453.65,1494.95,1465.0,1479.0,1484.95,1513.65,1579.9,1615.0,1568.35,1527.0,1496.7,1466.7,1482.0,1461.7,1446.85,1461.45,1458.0,1449.7,1454.0,1479.75,1472.0,1538.35,1540.0,1560.0,1589.5,1618.0,1618.4,1583.0,1579.55,1567.95,1593.0,1626.95,1648.55,1635.45,1665.0,1788.8,1804.2,1763.75,1772.7,1749.0,1752.0,1739.75,1741.0,1749.0,1767.6,1793.0,1858.0,1864.35,1834.95,1835.0,1884.6,1947.7,1941.7,1978.8,1869.0,1920.0,1932.0,1977.0,2010.0,2079.7,2163.0,2198.8,2194.0,2182.8,2139.7,2129.0,2057.0,2167.0,2196.0,2167.7,2157.8,2165.0,2160.0,2145.0,2138.9,2157.0,2105.0,2134.3,2154.0,2123.9,2122.0,2104.5,2111.3,2147.95,2150.0,2132.9,2174.0,2122.4,2138.0,2138.75,2096.95,2105.75,2121.0,2167.8,2344.95,2337.85,2360.0,2325.75,2369.35,2333.7,2319.45,2336.0,2277.0,2276.75,2226.0,2212.8,2238.0,2264.0,2267.0,2263.8,2249.15,2233.9,2309.0,2268.0,2253.0,2255.75,2285.75,2304.0,2290.0,2232.5,2228.7,2193.0,2192.0,2132.5,2135.0,2101.95,2059.85,2057.7,2042.0,2065.1,2027.0,1909.0,1929.0,1960.95,2040.0,2069.0,2090.0,2095.0,2008.45,2036.65,2015.3,2085.0,2006.5,2010.45,1983.8,1970.0,1974.0,1992.95,1965.0,1956.1],"low":[1505.5,1512.0, ...

# %%
plt.figure(figsize=(16,4));
plt.title('close price',fontsize=14);
plt.plot(data.Close);
plt.xlabel('time',fontsize=14);
plt.ylabel('price',fontsize=14);

# %%
data.tail()
# Out:
#            Date    Symbol Series  Prev Close     Open     High      Low  \
# 6200 2020-11-23  RELIANCE     EQ     1899.50  1951.00  1970.00  1926.25
# 6201 2020-11-24  RELIANCE     EQ     1950.70  1964.00  1974.00  1932.00
# 6202 2020-11-25  RELIANCE     EQ     1964.05  1980.00  1992.95  1942.20
# 6203 2020-11-26  RELIANCE     EQ     1947.80  1953.05  1965.00  1930.05
# 6204 2020-11-27  RELIANCE     EQ     1952.60  1940.50  1956.10  1921.40
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# 6200  1955.20  1950.70  1952.18  20918665  4.083700e+15  497781.0
# 6201  1971.05  1964.05  1952.11  14277083  2.787040e+15  362587.0
# 6202  1947.50  1947.80  1969.06  15062376  2.965870e+15  356793.0
# 6203  1957.00  1952.60  1946.67  11924527  2.321310e+15  266412.0
# 6204  1940.50  1929.80  1935.45  21845931  4.228160e+15  314085.0
#
#       Deliverable Volume  %Deliverble
# 6200           5148955.0       0.2461
# 6201           3213843.0       0.2251
# 6202           3040444.0       0.2019
# 6203           3406506.0       0.2857
# 6204          12489338.0       0.5717

# %%
fig1, ax = plt.subplots(1,1,figsize=(10,5),dpi=100)
sns.countplot(data=data,ax=ax)
ax.tick_params(axis='x', rotation=90)

# %%
data.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
data = data.drop(columns=['Symbol', 'Series', 'Last', 'Trades', 'Deliverable Volume','%Deliverble'], axis=1);

# %%
data = data[['Date','Prev Close','Open', 'High', 'Low', 'VWAP','Volume', 'Turnover','Close']];

# %%
data.head()
# Out:
#         Date  Prev Close    Open    High     Low    VWAP   Volume  \
# 0 1996-01-01      204.65  205.00  206.10  203.65  205.26  3717450
# 1 1996-01-02      205.75  205.25  206.25  202.65  204.13  6024650
# 2 1996-01-03      204.15  207.50  216.95  205.25  207.04  7473500
# 3 1996-01-04      205.70  203.75  204.40  201.05  202.47  7744000
# 4 1996-01-05      203.80  203.00  203.00  200.65  202.05  5952000
#
#        Turnover   Close
# 0  7.630000e+13  205.75
# 1  1.230000e+14  204.15
# 2  1.550000e+14  205.70
# 3  1.570000e+14  203.80
# 4  1.200000e+14  202.40

# %%
data.loc[5975,:]
# Out:
# Date          2020-01-01 00:00:00
# Prev Close                1514.05
# Open                       1518.0
# High                       1527.1
# Low                        1505.5
# VWAP                      1515.23
# Volume                    6402372
# Turnover        970000000000000.0
# Close                      1509.6
# Name: 5975, dtype: object

# %%
data.loc[5974,:]
# Out:
# Date          2019-12-31 00:00:00
# Prev Close                 1544.2
# Open                       1542.0
# High                       1543.7
# Low                       1508.05
# VWAP                      1525.14
# Volume                   10150467
# Turnover       1550000000000000.0
# Close                     1514.05
# Name: 5974, dtype: object

# %%
data = data.drop(columns=['Date'], axis=1);

# %%
data.info
# Out:
# <bound method DataFrame.info of       Prev Close     Open     High      Low     VWAP    Volume      Turnover  \
# 0         204.65   205.00   206.10   203.65   205.26   3717450  7.630000e+13
# 1         205.75   205.25   206.25   202.65   204.13   6024650  1.230000e+14
# 2         204.15   207.50   216.95   205.25   207.04   7473500  1.550000e+14
# 3         205.70   203.75   204.40   201.05   202.47   7744000  1.570000e+14
# 4         203.80   203.00   203.00   200.65   202.05   5952000  1.200000e+14
# ...          ...      ...      ...      ...      ...       ...           ...
# 6200     1899.50  1951.00  1970.00  1926.25  1952.18  20918665  4.083700e+15
# 6201     1950.70  1964.00  1974.00  1932.00  1952.11  14277083  2.787040e+15
# 6202     1964.05  1980.00  1992.95  1942.20  1969.06  15062376  2.965870e+15
# 6203     1947.80  1953.05  1965.00  1930.05  1946.67  11924527  2.321310e+15
# 6204     1952.60  1940.50  1956.10  1921.40  1935.45  21845931  4.228160e+15
#
#         Close
# 0      205.75
# 1      204.15
# 2      205.70
# 3      203.80
# 4      202.40
# ...       ...
# 6200  1950.70
# 6201  1964.05
# 6202  1947.80
# 6203  1952.60
# 6204  1929.80
#
# [6205 rows x 8 columns]>

# %%
# Scale the dataset
scaler = MinMaxScaler(feature_range=(0,1));
dataset = data.values.astype('float32')

# %%
dataset.shape
# Out:
# (6205, 8)

# %%
#  Perform separate scaling for training and testing data set to avoid DATA LEAKAGE

scaled1 = scaler.fit_transform(dataset[0:5974,:]); # Years until 2019
scaled2 = scaler.fit_transform(dataset[5974:6205,:]); # Year 2020

# %%
scaled1.shape
# Out:
# (5974, 8)

# %%
scaled2.shape
# Out:
# (231, 8)

# %%
scaled  = np.concatenate((scaled1, scaled2), axis=0);

# %%
scaled.shape
# Out:
# (6205, 8)

# %%
X_train = scaled[0:5974,0:-1]; # Years until 2019
X_train.shape
# Out:
# (5974, 7)

# %%
X_test = scaled[5974:-1,0:-1]; # Year 2020
X_test.shape
# Out:
# (230, 7)

# %%
Y_train = scaled[0:5974,-1];  # Years until 2019
Y_true  = scaled[5974:-1,-1]; # Year 2020

# %%
Y_train.shape,Y_true.shape
# Out:
# ((5974,), (230,))

# %%
plt.plot(Y_train) # scaled version of price action till 2019

# %%
# Reshape the data
X_train = np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1));
X_train.shape
# Out:
# (5974, 7, 1)

# %%
X_test = np.array(X_test);
# Reshape the data
X_test = np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1));
X_test.shape
# Out:
# (230, 7, 1)

# %%
# build the LSTM Model
LSTM_model = Sequential();
LSTM_model.add(LSTM(units = 50,return_sequences=True,input_shape = (X_train.shape[0],1)));
LSTM_model.add(LSTM(units = 50,return_sequences=False));
LSTM_model.add(Dense(25,activation='sigmoid')); # hidden layer
LSTM_model.add(Dropout(0.2));
LSTM_model.add(Dense(1,activation='sigmoid')); # output layer
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
LSTM_model.compile(loss = 'mean_squared_error',optimizer = 'adam');

# %%
history = LSTM_model.fit(X_train,Y_train,batch_size = 10,epochs = 5,validation_data=(X_test, Y_true));
plt.plot(history.history['loss'],label='train');
plt.plot(history.history['val_loss'],label='test');
plt.legend();
# Out:
# Epoch 1/5
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - loss: 0.0123 - val_loss: 0.0091
# Epoch 2/5
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0015 - val_loss: 0.0044
# Epoch 3/5
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - loss: 8.6253e-04 - val_loss: 0.0034
# Epoch 4/5
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 6.8890e-04 - val_loss: 0.0021
# Epoch 5/5
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 8.1874e-04 - val_loss: 0.0019

# %%
y_pred   = LSTM_model.predict(X_test);
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step

# %%
X_test   = X_test.reshape(X_test.shape[0],X_test.shape[1]);
datafwd  = np.concatenate((X_test, y_pred), axis=1);
inv_data = scaler.inverse_transform(datafwd);
ypred    = inv_data[:,-1];

# %%
plt.figure(figsize=(16,4));
plt.plot(data.Close);
index_2020 = list(range(5974,6204));
plt.plot(index_2020,ypred,label='LSTM predicted');
plt.legend();

# %%
plt.figure(figsize=(16,4));
plt.plot(data.Close[5974:6204],'r',label='truth');
index_2020 = list(range(5974,6204));
plt.plot(index_2020,ypred,'k',label='predicted');
plt.legend()
